# %% [markdown]
# 편집기 안에서 다음 단계를 완료하세요. <br>
# 변수를 생성 x하고 정수 5 를 할당하세요. <br>
# 변수를 생성 하고 부동소수점 값 3.14를y 할당하세요. <br>
# 변수를 생성 z하고 복소수 2+3j 를 할당하세요. <br>
# 각 변수의 유형을 출력하세요type() <br>

# %%
# 정수 생성
x = 5
# 부등소수점 생성
y = 3.14
# 복소수 생성
z = 2+3j
# type 출력
print(type(x), type(y),type(z))
