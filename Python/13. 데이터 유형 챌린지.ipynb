# %% [markdown]
# 편집기 안에서 다음 단계를 완료하세요. <br>
# x값이 5 인 변수를 생성하세요. <br>
# 3.14y 라는 값을 가진 변수를 생성하세요 . <br>
# "Hello"z 라는 값을 가진 변수를 생성하세요. <br>
# 각 변수의 데이터 유형을 출력하세요.type()

# %%
# 변수 생성
x = 5
y = 3.14
z = 'Hello'
# 각 변수의 데이터 타입 출력
print(type(x),type(y),type(z))
# Out:
# <class 'int'> <class 'float'> <class 'str'>
